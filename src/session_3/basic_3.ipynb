# %%
print("hell")
# Out:
# hell

# %%
base="C:/Users/mahmo/DEPI_GIZA_AIS4_S1_DS/src/session_3"
import os 
import sys

# %%
dir = os.listdir(base)
print(dir)
# Out:
# ['basic_3.ipynb']

# %%
import os 
directory  = ".temp_directory_test_again"
if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("Directory is alredy Exsist")
# Out:
# Directory is alredy Exsist

# %%
import os 
path  = ".temp_directory_test_again"
if not os.path.exists(path):
    os.makedirs(path)
for i in range (20):
    inner_path = os.path.join(path,"dir_"+str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)

# %%
def create_folders(path):
    if not os.path.exists(path):
        os.makedirs(path)
    for i in range (20):
        inner_path = os.path.join(path,"dir_"+str(i))
        if not os.path.exists(inner_path):
            os.makedirs(inner_path)

# %%
try :
    x = 10 
    y= int(input())
    x/y
except :
    print("Division by Zero")
# Out:
# Division by Zero

# %%
class StudentInfo :
    def __init__(self,student_name,age,Gpa,Gender):
        student_name = student_name
        age = age
        Gpa = Gpa
        Gender = Gender
    
    def student_info(self) :
        return f"welcome to {self.student_name}"

# %%
s1=StudentInfo("Hoda",25,3.55,"M")
s1.student_name
s1.student_info(self)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 s1=StudentInfo("Hoda",25,3.55,"M")
#       2 s1.student_name
#       3 s1.student_info(self)
#
# TypeError: StudentInfo() takes no arguments

# %%
class Calc:
    def __init__(self,num1:int , num2: int ):
        self.num1=num1
        self.num2 = num2
    def sum (self):
        return self.num1 + self.num2   
    def sum (self):
        return self.num1 - self.num2

# %%
c1= Calc(10 , 5)
c1.sum()
# Out:
# 5

# %%
from abc import ABC , abstractmethod 
class Animal(ABC):
    @abstractmethod
    def move(self):
        pass 
class Bird (Animal):
    
    def move(self):
        print ("Bird")

class Cat(Animal):
    
    def move(self):
        print("Cat")

# %%
a=Bird()
a.move()
# Out:
# Bird
